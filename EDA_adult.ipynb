# %%
import pandas as pd

# %%
train = pd.read_csv(r'C:\Users\irene\OneDrive\Υπολογιστής\TuE\BEP\Code\Bachelor-End-Project-Code---XAI\data\adult\adult.data')
test = pd.read_csv(r'C:\Users\irene\OneDrive\Υπολογιστής\TuE\BEP\Code\Bachelor-End-Project-Code---XAI\data\adult\adult_test')

# %%
train.shape
# Out:
# (32560, 15)

# %%
test.shape
# Out:
# (16281, 16)
